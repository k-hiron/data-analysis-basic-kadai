# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# Define the number of rows and columns
nrows = 1
ncols = 1

# Create the figure and axes
fig, axes = plt.subplots(2, 3, tight_layout=True)

#折れ線グラフ
y0 = [1, 2, -5, 2]
axes[0,0].plot(y0)

#sin関数
x = np.linspace(0, 10, 50)
y = 2 + 2 * np.sin(2 * x)
axes[0,1].plot(y)

#ヒストグラム
x = np.random .normal(0, 2, 30)
axes[0,2].hist(x, bins=30)

#散布図
np.random.seed(3)
x = 2 + np.random.normal(0, 2, 40)
y = 2 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)
axes[1,2]
# Out:
# <Axes: >

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
